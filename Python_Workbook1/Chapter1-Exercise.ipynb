# %% [markdown]
# ## EXERCISES
#
# **Instructions**
# + Create a new folder for each workbook (Example: Folder name = PythonWorkBook#1.
#   * Each folder will contain the notebooks for each chapter exercises including the challenges.
#
# + The notebook name should indicate the chapter where it belongs. (Example: Chapter1_exercises)
#
# * Create a new notebook for each chapter-exercises
#
# + Push the folder to your GitHub repo
#
# *Reminder*: Do not delete the file, and reupload to the GitHub. Push the updates back using `git` commands

# %% [markdown]
# #### Exercise 1
#
# * Each line of code below contains an **error**. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!') #The "P" in print is capitalized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Print('Hello world!')
#
# NameError: name 'Print' is not defined

# %%
print('Hello World')

# %%
print'Hello world!')
#There is no open parenthesis
# Out:
#   Cell In[18], line 1
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello World')

# %%
print('Hello world!)
#There is no qoutation after the "!"
# Out:
#   Cell In[19], line 1
#     print('Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello World')

# %%
print('Hello world!'')
#There is a double qoutation after the "!"
# Out:
#   Cell In[20], line 1
#     print('Hello world!'')
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello World')

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)

#There is no error
# Out:
# 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)
#The X on "X + 1" is capitalized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#
# NameError: name 'X' is not defined

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# # Save File

# %%
# !git config --global user.name "mariegrace10"

# %%
# !git config --global user.email "sorongonmariegrace@gmail.com"

# %%
# !git config --global user.password "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"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://mariegrace10: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@github.com/mariegrace10/AppDev_Sorongon.git
# !git clone git@github.com:mariegrace10/AppDev_Sorongon.git
# Out:
# Cloning into 'AppDev_Sorongon'...
# ...
# fatal: destination path 'AppDev_Sorongon' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter1-Exercise.ipynb" ""
