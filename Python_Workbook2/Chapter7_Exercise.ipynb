# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/ICT110
# Out:
# /content/drive/MyDrive/ICT110

# %%
with open('Hello.txt', 'r') as file:

    for line in file:

        print(line.upper(), end='')
# Out:
# HELLO WORLD
# HOLA MUNDO
# CIAO MONDO
# HALLO WERELD
# HEI VERDEN

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
with open('Hello.txt', 'r') as file:

    line_count = 0

    for line in file:

        line_count += 1

print("Number of lines in the file:", line_count)
# Out:
# Number of lines in the file: 5

# %% [markdown]
# ## CHALLENGE
#
# from [PEW] E8-2

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [raw]
# X-DSPAM-Confidence: 0.8475

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %%
with open('Hello.txt', 'r') as file:

    line_count = 0
    total_spam_confidence = 0.0

    for line in file:

        if line.startswith("X-DSPAM-Confidence:"):

            confidence_value = float(line.split(":")[1])

            line_count += 1
            total_spam_confidence += confidence_value

if line_count > 0:
    average_spam_confidence = total_spam_confidence / line_count
else:
    average_spam_confidence = 0.0

print("Average spam confidence:", average_spam_confidence)
# Out:
# Average spam confidence: 0.0
