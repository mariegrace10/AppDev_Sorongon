# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'

i = 0
print(text[4])     # n
print(text[2:4])   # si
print(text[:4])    # Busi
print(text[4:])    # ness Analytics
print(text[-2])    # c
print(text[-4:-2]) # ti
print(text[-2:])   #cs
print(text[:-2])   #Business Analyti
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

k = 0
print(phrase[0:3])
print(phrase[4:8])
print(phrase[21:28])
print(phrase[17:21])
print(phrase[0:25])
# Out:
# One
# Ring
#  all
# them
# One Ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
name = '  Marie Grace Sorongon'

name = name.lstrip()
name = name[0].upper() + name[1:].lower()
print(name)


#I strip my name into the left side
#I combined the 'capitalization' and the 'rest into smaller letters' through using string sliceds
# Out:
# Marie grace sorongon
